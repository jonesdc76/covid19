# %%
import sqlite3
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import seaborn as sns #nice plotting style
from matplotlib import style
#from matplotlib.dates import DateFormatter, DayLocator
import numpy as np
from datetime import datetime as dt
from dateutil import parser
# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

conn = sqlite3.connect(database)
c = conn.cursor()

# %%
c.execute("SELECT Date, Cases, Difference FROM covid_data WHERE Case_Type='Deaths'AND Country_Region='US' ORDER BY Date ASC")
data = c.fetchall()
x = [row[1] for row in data]
y = [row[2] for row in data]
dates = [dt.strptime(row[0],'%Y-%m-%d') for row in data]
ndays = (dates[-1] - dates[0]).days
day = 
#print("delta" + del.days)

fig, ax = plt.subplots(figsize=(10,8))
ax.hist()
ax.plot(dates, x,'-')
ax.set(xlabel="Day in 2020", 
       ylabel="Deaths", 
       title="Deaths from COVID-19 in the US")
#formatter = DateFormatter("%d")
locator = mdates.MonthLocator()
#locator = mdates.AutoDateLocator()
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(mdates.AutoDateFormatter(locator))
plt.xlabel("Day in 2020")
plt.show()
# Out:
# 69
